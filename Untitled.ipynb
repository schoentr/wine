# %%
import numpy as np
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy.polynomial.polynomial as poly
import pandas as pd
from sklearn.model_selection import train_test_split
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]

# %%
df = pd.read_csv('./wine-reviews/broadband-speed-test.csv')
df[:3]
# Out:
#    id  actual_download  actual_upload  advertised_download  advertised_upload  \
# 0   1           530.17         253.08                  NaN                NaN
# 1   2            24.34          48.62                  NaN                NaN
# 2   3            10.34          42.77                  NaN                NaN
#
#         connection cost_of_service                    date_pretty  \
# 0            wired       dont_know  Wed, 10 Feb 2016 12:58:16 GMT
# 1  wireless-single           50_75  Wed, 10 Feb 2016 13:56:47 GMT
# 2  wireless-single    100_or_above  Wed, 10 Feb 2016 13:58:08 GMT
#
#                                                  isp isp_user  min_rtt  \
# 0  AS2828 MCI Communications Services, Inc. d/b/a...       XO      2.0
# 1                        AS174 Cogent Communications  comcast      2.0
# 2                        AS174 Cogent Communications  comcast      2.0
#
#     timestamp  seattle_blkgrpce10
# 0  1455109096                 NaN
# ...

# %%
wired_comcast= df[df.isp_user == 'comcast']
wired_comcast= wired_comcast[wired_comcast.connection =='wired']
wired_comcast
# Out:
#         id  actual_download  actual_upload  advertised_download  \
# 18      19            47.84           5.90                  NaN
# 35      36            91.24          11.99                 20.0
# 36      37            11.02          10.06                  NaN
# 37      38            13.24           2.52                 12.0
# 39      40            56.50           5.84                 25.0
# 59      60            21.24           9.45                  NaN
# 60      61            26.75          11.28                  NaN
# 61      62            56.02           5.90                  5.0
# 65      66            69.62          34.95                  NaN
# 70      71           114.30          11.43                  NaN
# 71      72           118.90           1.91                  NaN
# 72      73            16.32           5.94                  NaN
# 81      82           118.23          23.73                  NaN
# 84      85            77.28           6.98                  NaN
# ...

# %%
wired_comcast[:1].connection
# Out:
# 1    wireless-single
# Name: connection, dtype: object

# %%
with open('./wine-reviews/broadband-speed-test.csv') as f:
    reader = csv.DictReader(f)
    print (reader.fieldnames)
