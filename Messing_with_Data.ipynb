# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import numpy.polynomial.polynomial as poly
import pandas as pd
from sklearn.model_selection import train_test_split
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]

# %%
wine_frame = pd.read_csv('./wine-reviews/wine_data_2.csv')
wine_frame= wine_frame[wine_frame.price <= 450]
wine_frame =wine_frame.drop_duplicates(subset='title', keep='first', inplace=False)

# %%
bordeaux_style_frame = wine_frame[wine_frame.variety=='Bordeaux-style Red Blend']
wa_bordeaux_style_frame = bordeaux_style_frame[bordeaux_style_frame.province=='Washington']

# %%
df_filtered = wine_frame.query('winery == "Andrew Will" | winery  == "DeLille"')

# %%
df_filtered[['title','points','price']]
# Out:
#                                                     title  points  price
# 3023    DeLille 2011 Chaleur Estate Blanc Sauvignon Bl...      92   37.0
# 3064    DeLille 2009 Chaleur Estate Blanc White (Colum...      95   36.0
# 3654    Andrew Will 2005 Ciel du Cheval Vineyard Red W...      92   60.0
# 4168             DeLille 2014 Doyenne Red (Yakima Valley)      92   42.0
# 4740    Andrew Will 1999 Ciel du Cheval Sangiovese (Ya...      90   23.0
# 5244           DeLille 2013 D2 Red (Columbia Valley (WA))      91   45.0
# 5590    Andrew Will 2005 Ciel du Cheval Vineyard Sangi...      86   25.0
# 10045   Andrew Will 2011 Two Blondes Vineyard Red (Yak...      89   55.0
# 12153   DeLille 2012 Grand Ciel Cabernet Sauvignon (Re...      91  160.0
# 13459   Andrew Will 2005 Sheridan Vineyard Red Wine Re...      89   60.0
# 15148   DeLille 2014 Four Flags Cabernet Sauvignon (Re...      93   69.0
# 15592      DeLille 2012 Chaleur Estate Red (Red Mountain)      92   85.0
# ...
